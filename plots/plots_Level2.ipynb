# %%
import tables
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import h5py

# %%
corsika1=tables.open_file('/mnt/ceph1-npx/user/hhamdaoui/MC_nuclearites/ANA1_L0_trigg/new_dir_R1100_d1000_1e+15_nevent_10000_nuclearite_IC86__beta_0001_0001__trigger_level__baseline__proc_0000.hd5')

# %%
corsika1.root
min(corsika1.root.Number_doms.col('value'))
# Out:
# 1404.0

# %%
plt.hist(corsika1.root.Number_doms.col('value'))
# Out:
# (array([  3.,   3.,   9.,   9.,  27., 106., 212., 346., 234.,  39.]),
#  array([1404. , 1661.2, 1918.4, 2175.6, 2432.8, 2690. , 2947.2, 3204.4,
#         3461.6, 3718.8, 3976. ]),
#  <BarContainer object of 10 artists>)

# %%
corsika_l2='/data/user/hhamdaoui/MC_nuclearites/h5/corsika/level2/merged/'

# %%
corsika1=tables.open_file(corsika_l2+'20783.hdf')

# %%
corsika1.root
# Out:
# / (RootGroup) ''
#   children := ['__I3Index__' (Group), 'LineFit' (Table)]

# %%
data=tables.open_file('/mnt/ceph1-npx/user/hhamdaoui/MC_nuclearites/ANA1_L0_trigg/exprm__IC86_08__runs_00132850_00132920.hd5')
# Out:
# ---------------------------------------------------------------------------
# HDF5ExtError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data=tables.open_file('/mnt/ceph1-npx/user/hhamdaoui/MC_nuclearites/ANA1_L0_trigg/exprm__IC86_08__runs_00132850_00132920.hd5')
#
# File /data/user/hhamdaoui/my_virtual_env/my_NNMFIt/lib/python3.10/site-packages/tables/file.py:300, in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     295             raise ValueError(
#     296                 "The file '%s' is already opened.  Please "
#     297                 "close it before reopening in write mode." % filename)
#     299 # Finally, create the File instance, and return it
# --> 300 return File(filename, mode, title, root_uep, filters, **kwargs)
#
# File /data/user/hhamdaoui/my_virtual_env/my_NNMFIt/lib/python3.10/site-packages/tables/file.py:750, in File.__init__(self, filename, mode, title, root_uep, filters, **kwargs)
# ...

# %%
data.root.SLOPTuples_CosAlpha_Launches.col('item')
# Out:
# array([-0.94546341, -0.93996237, -0.87614746, ..., -0.88514991,
#        -0.77855697, -0.78793059])

# %%
grl=pd.read_csv('/data/user/hhamdaoui/nuclearite_analysis/IC86_2019_GoodRunInfo.txt',sep=' ',header=0)

# %%
list(grl)
# Out:
# ['RunNum',
#  'Good_i3',
#  'Good_it',
#  'LiveTime',
#  'ActiveStrings',
#  'ActiveDoms',
#  'ActiveInIce',
#  'OutDir',
#  'Comment(s)']

# %%
grl['OutDir']
# Out:
# 0       /data/exp/IceCube/2019/filtered/level2/0628/Ru...
# 1       /data/exp/IceCube/2019/filtered/level2/0629/Ru...
# 2       /data/exp/IceCube/2019/filtered/level2/0629/Ru...
# 3       /data/exp/IceCube/2019/filtered/level2/0718/Ru...
# 4       /data/exp/IceCube/2019/filtered/level2/0718/Ru...
#                               ...
# 1111    /data/exp/IceCube/2020/filtered/level2/0528/Ru...
# 1112    /data/exp/IceCube/2020/filtered/level2/0528/Ru...
# 1113    /data/exp/IceCube/2020/filtered/level2/0528/Ru...
# 1114    /data/exp/IceCube/2020/filtered/level2/0529/Ru...
# 1115    /data/exp/IceCube/2020/filtered/level2/0529/Ru...
# Name: OutDir, Length: 1116, dtype: object

# %%
grl['OutDir_str']=grl['OutDir'].values.astype('str')

# %%
burn=grl['OutDir'].str.endswith('0')

# %%
2717017.81

# %%
np.sum(grl['LiveTime'])
# Out:
# 27068243.49

# %%
for i in grl['OutDir']:
    if i.endswith('0'):
        print(i)

# %%
corsika=tables.open_file('/data/user/hhamdaoui/nuclearite_analysis/genscripts/test_corsika_L2.h5')

# %%
corsika.root.SLOPKalman_LineFit.col('zenith')
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
base_path='/data/user/hhamdaoui/MC_nuclearites/h5/MC3_L2_northprocessed/'
m5e12=tables.open_file(base_path+'new_dir_R1100_d1000_5e+12_nevent_10000_nuclearite_IC86__beta_0001_0001__trigger_level__baseline__proc_0000.h5')
m13=tables.open_file(base_path+'new_dir_R1100_d1000_1e+13_nevent_10000_nuclearite_IC86__beta_0001_0001__trigger_level__baseline__proc_0000.h5')
m14=tables.open_file(base_path+'new_dir_R1100_d1000_1e+14_nevent_10000_nuclearite_IC86__beta_0001_0001__trigger_level__baseline__proc_0000.h5')
m15=tables.open_file(base_path+'new_dir_R1100_d1000_1e+15_nevent_10000_nuclearite_IC86__beta_0001_0001__trigger_level__baseline__proc_0000.h5')
m16=tables.open_file(base_path+'new_dir_R1100_d1000_1e+16_nevent_10000_nuclearite_IC86__beta_0001_0001__trigger_level__baseline__proc_0000.h5')
m17=tables.open_file(base_path+'new_dir_R1100_d1000_1e+17_nevent_10000_nuclearite_IC86__beta_0001_0001__trigger_level__baseline__proc_0000.h5')
data=tables.open_file('/data/user/hhamdaoui/MC_nuclearites/h5/data/Level2_IC86.2018_data_Run00131986_Subrun00000000_00000003.i3.zst.h5')
#muongun=tables.open_file('/data/user/hhamdaoui/MC_nuclearites/h5/muongunLevel2_IC86.2020_MuonGun.021534.000176.i3.zst.h5')
#corsika=tables.open_file('/data/user/hhamdaoui/MC_nuclearites/h5/corsikaLevel2_IC86.2016_corsika.020783.000661.i3.zst.h5')

# %%
max(m13.root.CVMultiplicity.col('n_hit_doms'))
# Out:
# 22

# %%
plt.hist(m5e12.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='5e12',density=True)
plt.hist(m13.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m13',density=True)
plt.hist(m14.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m14',density=True)
plt.hist(m15.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m15',density=True)
plt.hist(m16.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m16',density=True)
plt.hist(m17.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m17',density=True)
plt.hist(muongun.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='2020_MuonGun.021534',density=True)
plt.hist(corsika.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='2016_corsika.020783',density=True)
plt.hist(data.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='data',density=True,color='black')
plt.loglog()
plt.legend()
plt.xlabel('n_hit_doms')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
plt.hist(np.cos(m13.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='m13',density=True)
plt.hist(np.cos(m14.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='m14',density=True)
plt.hist(np.cos(m15.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='m15',density=True)
plt.hist(np.cos(m16.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='m16',density=True)
plt.hist(np.cos(m17.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='m17',density=True)
plt.hist(np.cos(data.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='data',density=True,color='black')
plt.hist(np.cos(muongun.root.LineFit.col('zenith')),histtype='step',label='2020_MuonGun.021534',density=True)
plt.hist(np.cos(corsika.root.LineFit.col('zenith')),histtype='step',label='2016_corsika.020783',density=True)

plt.legend()
plt.xlabel(r'$cos zenith~linefit$')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
density=True
plt.hist(m5e12.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m5e12',density=density)
plt.hist(m13.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m13',density=density)
plt.hist(m14.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m14',density=density)
plt.hist(m15.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m15',density=density)
plt.hist(m16.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m16',density=density)
plt.hist(m17.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m17',density=density)
plt.hist(corsika.root.LineFit.col('speed'),histtype='step',label='2016_corsika.020783',density=density)
plt.hist(muongun.root.LineFit.col('speed'),histtype='step',label='2020_MuonGun.021534',density=density)
plt.hist(data.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='data',density=density,color='black')

plt.yscale('log')
plt.xscale('log')

plt.legend()
plt.xlabel(r'$speed~linefit$')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
density=True
plt.hist(m5e12.root.CVStatistics.col('q_tot_pulses'),histtype='step',label='m5e12',density=density)
plt.hist(m13.root.CVStatistics.col('q_tot_pulses'),histtype='step',label='m13',density=density)
plt.hist(m14.root.CVStatistics.col('q_tot_pulses'),histtype='step',label='m14',density=density)
plt.hist(m15.root.CVStatistics.col('q_tot_pulses'),histtype='step',label='m15',density=density)
plt.hist(m16.root.CVStatistics.col('q_tot_pulses'),histtype='step',label='m16',density=density)
plt.hist(m17.root.CVStatistics.col('q_tot_pulses'),histtype='step',label='m17',density=density)
plt.hist(corsika.root.CVStatistics.col('q_tot_pulses'),histtype='step',label='2016_corsika.02078',density=density)
plt.hist(muongun.root.CVStatistics.col('q_tot_pulses'),histtype='step',label='2020_MuonGun.021534',density=density)

plt.hist(data.root.CVStatistics.col('q_tot_pulses'),histtype='step',label='data',density=density,color='black')

plt.yscale('log')
plt.xscale('log')

plt.legend()
plt.xlabel(r'q_tot_pulses')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
plt.hist(m13.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='m13')
plt.hist(m14.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='m14')
plt.hist(m15.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='m15')
plt.hist(m16.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='m16')
plt.hist(m17.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='m17')
plt.hist(data.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='data',color='black')
plt.yscale('log')

plt.legend()
plt.xlabel(r'$Cos(\alpha)~$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
masses=[m5e12,m13,m14,m15,m16,m17]
masslabel={
    m5e12:'5e12',
    m13:'1e13',
    m14:'1e14',
    m15:'1e15',
    m16:'1e16',
    m17:'1e17',
}

# %%
effarea=[]
masslist=[]

for m in masses:
    print(masslabel[m])
    Aeff=500*500*3.14*len(m.root.SLOPTuples_RelV_Launches.col('item'))/10000
    print(masslabel[m],Aeff)
    effarea.append(Aeff)
    masslist.append(float(masslabel[m]))
# Out:
# 5e12
# 5e12 416364.0
# 1e13
# 1e13 389046.0
# 1e14
# 1e14 313215.0
# 1e15
# 1e15 370284.5
# 1e16
# 1e16 437794.5
# 1e17
# 1e17 495570.5

# %%
effarea
# Out:
# [416364.0, 389046.0, 313215.0, 370284.5, 437794.5, 495570.5]

# %%
masslist
# Out:
# [5000000000000.0,
#  10000000000000.0,
#  100000000000000.0,
#  1000000000000000.0,
#  1e+16,
#  1e+17]

# %%
plt.plot(masslist,effarea)
plt.xscale('log')
plt.yscale('log')

plt.xlabel('mass[GeV]')
plt.ylabel('effarea[m^2]')
# Out:
# Text(0, 0.5, 'effarea[m^2]')

# %%
len(m16.root.SLOPTuples_RelV_Launches.col('item'))/10000
# Out:
# 0.4799

# %%
6573/10000
# Out:
# 0.6573

# %%
len(m17.root.SLOPTuples_LineFit.col('speed'))
# Out:
# 1033

# %%
2390/5000 *100
# Out:
# 47.8

# %%
plt.hist(m5e12.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m13',density=True)
plt.hist(m13.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m13',density=True)
plt.hist(m14.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m14',density=True)
plt.hist(m15.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m15',density=True)
plt.hist(m16.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m16',density=True)
plt.hist(m17.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m17',density=True)
plt.hist(muongun.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='muongun',density=True)
plt.hist(corsika.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='corsika',density=True)
plt.hist(data.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='data',density=True,color='black')
plt.loglog()
plt.legend()
plt.xlabel('n_hit_doms')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
plt.hist(m5e12.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m13',density=True)
plt.hist(m13.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m13',density=True)
plt.hist(m14.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m14',density=True)
plt.hist(m15.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m15',density=True)
plt.hist(m16.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m16',density=True)
plt.hist(m17.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='m17',density=True)
plt.hist(muongun.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='muongun',density=True)
plt.hist(corsika.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='corsika',density=True)
plt.hist(data.root.CVMultiplicity.col('n_hit_doms'),histtype='step',label='data',density=True,color='black')
plt.loglog()
plt.legend()
plt.xlabel('n_hit_doms')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
#density=False,weights=np.ones(len(np.cos(m13.root.SLOPTuples_LineFit.col('zenith')))) / len(np.cos(m13.root.SLOPTuples_LineFit.col('zenith'))))

# %%
plt.hist(np.cos(m13.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='m13',density=True)
plt.hist(np.cos(m14.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='m14',density=True)
plt.hist(np.cos(m15.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='m15',density=True)
plt.hist(np.cos(m16.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='m16',density=True)
plt.hist(np.cos(m17.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='m17',density=True)
plt.hist(np.cos(data.root.SLOPTuples_LineFit.col('zenith')),histtype='step',label='data',density=True,color='black')

plt.legend()
plt.xlabel(r'$cos zenith~linefit$')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
density=True
plt.hist(m13.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m13',density=density)
plt.hist(m14.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m14',density=density)
plt.hist(m15.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m15',density=density)
plt.hist(m16.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m16',density=density)
plt.hist(m17.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m17',density=density)
plt.hist(data.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='data',density=density,color='black')
plt.yscale('log')

plt.legend()
plt.xlabel(r'$speed~linefit$')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
plt.hist(m13.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='m13')
plt.hist(m14.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='m14')
plt.hist(m15.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='m15')
plt.hist(m16.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='m16')
plt.hist(m17.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='m17')
plt.hist(data.root.SLOPTuples_CosAlpha_Launches.col('item'),histtype='step',label='data',color='black')
plt.yscale('log')

plt.legend()
plt.xlabel(r'$Cos(\alpha)~$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.hist(m13.root.SLOPTuples_RelV_Launches.col('item'),histtype='step',label='m13')
plt.hist(m14.root.SLOPTuples_RelV_Launches.col('item'),histtype='step',label='m14')
plt.hist(m15.root.SLOPTuples_RelV_Launches.col('item'),histtype='step',label='m15')
plt.hist(m16.root.SLOPTuples_RelV_Launches.col('item'),histtype='step',label='m16')
plt.hist(m17.root.SLOPTuples_RelV_Launches.col('item'),histtype='step',label='m17')
plt.hist(data.root.SLOPTuples_RelV_Launches.col('item'),histtype='step',label='data',color='black')
#plt.yscale('log')

plt.legend()
plt.xlabel(r'$v_{rel}$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
density=True

plt.hist(m13.root.SLOPPulseMask.col('charge'),histtype='step',label='m13',density=density)
plt.hist(m14.root.SLOPPulseMask.col('charge'),histtype='step',label='m14',density=density)
plt.hist(m15.root.SLOPPulseMask.col('charge'),histtype='step',label='m15',density=density)
plt.hist(m16.root.SLOPPulseMask.col('charge'),histtype='step',label='m16',density=density)
plt.hist(m17.root.SLOPPulseMask.col('charge'),histtype='step',label='m17',density=density)
plt.hist(data.root.SLOPPulseMask.col('charge'),histtype='step',label='data',density=density,color='black')
plt.legend()

plt.legend()
plt.xlabel(r'$charge$')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
density=True

plt.hist(m13.root.SLOPLaunchMapTuples.col('string'),histtype='step',label='m13',density=density)
plt.hist(m14.root.SLOPLaunchMapTuples.col('string'),histtype='step',label='m14',density=density)
plt.hist(m15.root.SLOPLaunchMapTuples.col('string'),histtype='step',label='m15',density=density)
plt.hist(m16.root.SLOPLaunchMapTuples.col('string'),histtype='step',label='m16',density=density)
plt.hist(m17.root.SLOPLaunchMapTuples.col('string'),histtype='step',label='m17',density=density)
plt.hist(data.root.SLOPLaunchMapTuples.col('string'),histtype='step',label='data',density=density,color='black')
plt.legend()

plt.legend()
plt.xlabel(r'String')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
density=True

plt.hist(m13.root.SLOPLaunchMapTuples.col('om'),histtype='step',label='m13',density=density)
plt.hist(m14.root.SLOPLaunchMapTuples.col('om'),histtype='step',label='m14',density=density)
plt.hist(m15.root.SLOPLaunchMapTuples.col('om'),histtype='step',label='m15',density=density)
plt.hist(m16.root.SLOPLaunchMapTuples.col('om'),histtype='step',label='m16',density=density)
plt.hist(m17.root.SLOPLaunchMapTuples.col('om'),histtype='step',label='m17',density=density)
plt.hist(data.root.SLOPLaunchMapTuples.col('om'),histtype='step',label='data',density=density,color='black')
plt.legend()

plt.legend()
plt.xlabel(r'om')
plt.ylabel('a.u ')
# Out:
# Text(0, 0.5, 'a.u ')

# %%
SLOPLaunchMapTuples.col('string')

# %%
plt.hist(m17.root.SLOPLaunchMapTuples.col('string'))
plt.hist(m17.root.SLOPLaunchMapTuples.col('om'))

# %%
l6=tables.open_file('/data/user/hhamdaoui/nuc-analysis/output/ANA3_L2_anacut/mmact_190617_monopole_IC86__beta_0750_0995__trigger_level__baseline__proc_0345.hd5')

# %%
cosz=l6.root.ABurgmanVars.col('opcoszen')

# %%
len(cosz)
# Out:
# 250

# %%
import matplotlib.pyplot as plt
plt.hist(cosz)
# Out:
# (array([17., 31., 24., 31., 25., 19., 34., 35., 15., 19.]),
#  array([-9.99563198e-01, -7.99820381e-01, -6.00077563e-01, -4.00334746e-01,
#         -2.00591928e-01, -8.49110770e-04,  1.98893707e-01,  3.98636524e-01,
#          5.98379342e-01,  7.98122159e-01,  9.97864977e-01]),
#  <BarContainer object of 10 artists>)

# %%
mm=tables.open_file('/mnt/ceph1-npx/ana/BSM/IC86_LowRelativisticMonopoles/cut_level_hdf_files/lv03/monosim-00000500-spice_3.2.1_01_500_0.6_MMCommonVariables_monosim.hdf')
plt.hist(mm.root.data.CommonVariablesIC.col('NHitDoms'))
plt.hist(m17.root.SLOPDSTPulseMask.col('om'))
plt.hist(data.root.SLOPKalman_LineFit.col('zenith')-data.root.SLOPTuples_LineFit.col('zenith'),histtype='step',label='m13')
plt.hist(data.root.SLOPKalman_LineFit.col('speed')-data.root.SLOPTuples_LineFit.col('speed'),histtype='step',label='m13',bins=30)
